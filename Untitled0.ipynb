# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/Text2image/
# Out:
# /content/gdrive/My Drive/Text2image

# %%
from PIL import Image, ImageDraw, ImageFont

def create_image_with_text(text):
    # Choose Times New Roman-like font and adjust font size
    font_size = 60
    font = ImageFont.load_default()  # Default system font

    # Create a temporary image to calculate text size
    temp_img = Image.new("RGB", (1, 1))
    temp_draw = ImageDraw.Draw(temp_img)
    temp_font = ImageFont.truetype("times.ttf", font_size)  # Times New Roman-like font

    # Calculate text size
    text_width, text_height = temp_draw.textsize(text, font=temp_font)

    # Set image dimensions based on text size with padding
    padding = 20
    width = text_width + padding
    height = text_height + padding

    # Create a new image with white background
    img = Image.new("RGB", (width, height), (255, 255, 255))  # White color in RGB

    # Create a drawing context
    draw = ImageDraw.Draw(img)

    # Calculate text position to center it
    text_x = (width - text_width) / 2
    text_y = (height - text_height) / 2

    # Draw text on the image
    draw.text((text_x, text_y), text, fill="black", font=temp_font)

    # Save the image as a PNG file
    img.save("text_image.png")

# Get user input for text
user_text = input("Enter the text you want in the image: ")

# Call the function to create the image with the entered text
create_image_with_text(user_text)
# Out:
# Enter the text you want in the image: hjhgkhhgflgkj;
# <ipython-input-7-afc65643345a>:14: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   text_width, text_height = temp_draw.textsize(text, font=temp_font)
